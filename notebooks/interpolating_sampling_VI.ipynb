# %% [markdown]
# ## Notebook for interpolating sampling and VI

# %%
# %pylab inline
import sys, importlib
import numpy as np
import torch
import time
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Set up a very simple Boltzmann Machine
# # I might want to eventually try this with mean-field VI, where we sample from phi(theta) for each node sequentially.

# %%
# set noise seed
noise_seed = 2022
np.random.seed(noise_seed)
torch.manual_seed(noise_seed)
print('noise_seed = %d' %(noise_seed))
# Out:
# noise_seed = 2022
